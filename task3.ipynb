# %%
import pandas as pd

# %%
data= pd.read_csv('2023 QS World University Rankings.csv')

# %%
data.head()
# Out:
#    Rank                                   Institution LocationCode  \
# 0     1  Massachusetts Institute of Technology (MIT)            US
# 1     2                       University of Cambridge           UK
# 2     3                           Stanford University           US
# 3     4                          University of Oxford           UK
# 4     5                            Harvard University           US
#
#          Location  ArScore ArRank  ErScore ErRank  FsrScore FsrRank  ...  \
# 0   United States    100.0      5    100.0      4     100.0      14  ...
# 1  United Kingdom    100.0      2    100.0      2     100.0      11  ...
# 2   United States    100.0      4    100.0      5     100.0       6  ...
# 3  United Kingdom    100.0      3    100.0      3     100.0       8  ...
# 4   United States    100.0      1    100.0      1      99.4      35  ...
#
#    CpfRank IfrScore  IfrRank IsrScore  IsrRank IrnScore  IrnRank GerScore  \
# ...

# %%
data.dtypes
# Out:
# Rank              int64
# Institution      object
# LocationCode     object
# Location         object
# ArScore         float64
# ArRank           object
# ErScore         float64
# ErRank           object
# FsrScore        float64
# FsrRank          object
# CpfScore        float64
# CpfRank          object
# IfrScore        float64
# IfrRank          object
# IsrScore        float64
# IsrRank          object
# IrnScore        float64
# IrnRank          object
# GerScore        float64
# GerRank          object
# ScoreScaled      object
# dtype: object

# %%
data[["Rank"]] = data[["Rank"]].astype("float")
data[["ArScore"]] = data[["ArScore"]].astype("int")

# %%
data.dtypes
# Out:
# Rank            float64
# Institution      object
# LocationCode     object
# Location         object
# ArScore           int32
# ArRank           object
# ErScore         float64
# ErRank           object
# FsrScore        float64
# FsrRank          object
# CpfScore        float64
# CpfRank          object
# IfrScore        float64
# IfrRank          object
# IsrScore        float64
# IsrRank          object
# IrnScore        float64
# IrnRank          object
# GerScore        float64
# GerRank          object
# ScoreScaled      object
# dtype: object

# %%
data.head()
# Out:
#    Rank                                   Institution LocationCode  \
# 0   1.0  Massachusetts Institute of Technology (MIT)            US
# 1   2.0                       University of Cambridge           UK
# 2   3.0                           Stanford University           US
# 3   4.0                          University of Oxford           UK
# 4   5.0                            Harvard University           US
#
#          Location  ArScore ArRank  ErScore ErRank  FsrScore FsrRank  ...  \
# 0   United States      100      5    100.0      4     100.0      14  ...
# 1  United Kingdom      100      2    100.0      2     100.0      11  ...
# 2   United States      100      4    100.0      5     100.0       6  ...
# 3  United Kingdom      100      3    100.0      3     100.0       8  ...
# 4   United States      100      1    100.0      1      99.4      35  ...
#
#    CpfRank IfrScore  IfrRank IsrScore  IsrRank IrnScore  IrnRank GerScore  \
# ...

# %%
import numpy as np

# replace "?" to NaN
data.replace("?", np.nan, inplace = True)
data.head(7)
# Out:
#    Rank                                   Institution LocationCode  \
# 0   1.0  Massachusetts Institute of Technology (MIT)            US
# 1   2.0                       University of Cambridge           UK
# 2   3.0                           Stanford University           US
# 3   4.0                          University of Oxford           UK
# 4   5.0                            Harvard University           US
# 5   6.0  California Institute of Technology (Caltech)           US
# 6   7.0                       Imperial College London           UK
#
#          Location  ArScore ArRank  ErScore ErRank  FsrScore FsrRank  ...  \
# 0   United States      100      5    100.0      4     100.0      14  ...
# 1  United Kingdom      100      2    100.0      2     100.0      11  ...
# 2   United States      100      4    100.0      5     100.0       6  ...
# 3  United Kingdom      100      3    100.0      3     100.0       8  ...
# ...

# %%
missing_data = data.isnull()
missing_data.head(7)
# Out:
#     Rank  Institution  LocationCode  Location  ArScore  ArRank  ErScore  \
# 0  False        False         False     False    False   False    False
# 1  False        False         False     False    False   False    False
# 2  False        False         False     False    False   False    False
# 3  False        False         False     False    False   False    False
# 4  False        False         False     False    False   False    False
# 5  False        False         False     False    False   False    False
# 6  False        False         False     False    False   False    False
#
#    ErRank  FsrScore  FsrRank  ...  CpfRank  IfrScore  IfrRank  IsrScore  \
# 0   False     False    False  ...    False     False    False     False
# 1   False     False    False  ...    False     False    False     False
# 2   False     False    False  ...    False     False    False     False
# 3   False     False    False  ...    False     False    False     False
# ...

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Rank
# False    1422
# Name: Rank, dtype: int64
#
# Institution
# False    1422
# Name: Institution, dtype: int64
#
# LocationCode
# False    1422
# Name: LocationCode, dtype: int64
#
# Location
# False    1422
# Name: Location, dtype: int64
#
# ArScore
# False    1422
# Name: ArScore, dtype: int64
#
# ArRank
# False    1422
# Name: ArRank, dtype: int64
#
# ErScore
# False    1421
# True        1
# Name: ErScore, dtype: int64
#
# ErRank
# False    1422
# Name: ErRank, dtype: int64
#
# FsrScore
# False    1420
# True        2
# Name: FsrScore, dtype: int64
#
# FsrRank
# False    1422
# Name: FsrRank, dtype: int64
#
# CpfScore
# False    1417
# True        5
# Name: CpfScore, dtype: int64
#
# CpfRank
# False    1422
# Name: CpfRank, dtype: int64
#
# IfrScore
# False    1324
# True       98
# Name: IfrScore, dtype: int64
#
# IfrRank
# False    1324
# True       98
# Name: IfrRank, dtype: int64
#
# IsrScore
# False    1365
# True       57
# Name: IsrScore, dtype: int64
#
# IsrRank
# ...

# %%
data["IrnRank"].replace(np.nan, avg_norm_loss, inplace=True)
data["Location"].replace(np.nan, avg_norm_loss, inplace=True)

# %%
data.head()
# Out:
#    Rank                                   Institution LocationCode  \
# 0   1.0  Massachusetts Institute of Technology (MIT)            US
# 1   2.0                       University of Cambridge           UK
# 2   3.0                           Stanford University           US
# 3   4.0                          University of Oxford           UK
# 4   5.0                            Harvard University           US
#
#          Location  ArScore ArRank  ErScore ErRank  FsrScore FsrRank  ...  \
# 0   United States      100      5    100.0      4     100.0      14  ...
# 1  United Kingdom      100      2    100.0      2     100.0      11  ...
# 2   United States      100      4    100.0      5     100.0       6  ...
# 3  United Kingdom      100      3    100.0      3     100.0       8  ...
# 4   United States      100      1    100.0      1      99.4      35  ...
#
#    CpfRank IfrScore  IfrRank IsrScore  IsrRank IrnScore  IrnRank GerScore  \
# ...
